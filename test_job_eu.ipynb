# %%
from datetime import datetime
from os import environ
import sagemaker
from sagemaker.estimator import Estimator
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/xdg-ubuntu/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/alexia/.config/sagemaker/config.yaml

# %% [markdown]
# ## Build and push image
#
# Change the env vars in the shell scripts, according to your project

# %%
data_center = "eu"

if data_center == "us":
    bucket = "quicklizard"
    aws_region = "us-east-1"
elif data_center == "eu":
    bucket = "quicklizard-eu-central"
    aws_region = "eu-central-1"

# img_tag = "qa-1.0"
img_tag = "0.1.1"
proj_name = "elasticity"
environ["AWS_REGION"] = aws_region
environ["AWS_DEFAULT_REGION"] = aws_region

# aws ecr create-repository --repository-name $PROJ_NAME --region $AWS_REGION

# %%
# %%sh -s $img_tag $proj_name
# make TAG="$1" PROJ="$2"
#
# # chmod 755 containerize_m1.sh
# # ./containerize_m1.sh "$1"
# Out:
# Building docker image elasticity:0.1.1 for US data center
# DOCKER_BUILDKIT=1 docker build --platform linux/amd64 --ssh default -t 444642203706.dkr.ecr.us-east-1.amazonaws.com/elasticity:0.1.1 .
# #0 building with "default" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 682B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.11.6-slim-bookworm
# #2 ...
#
# #3 [auth] library/python:pull token for registry-1.docker.io
# #3 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.11.6-slim-bookworm
# #2 DONE 2.5s
#
# #4 [internal] load .dockerignore
# #4 transferring context: 300B done
# #4 DONE 0.0s
#
# #5 [1/9] FROM docker.io/library/python:3.11.6-slim-bookworm@sha256:cc758519481092eb5a4a5ab0c1b303e288880d59afc601958d19e95b300bc86b
# #5 DONE 0.0s
#
# #6 [internal] load build context
# #6 transferring context: 3.04kB done
# #6 DONE 0.0s
#
# #7 [3/9] COPY src/elasticity/ /usr/bin/elasticity
# #7 CACHED
#
# #8 [6/9] COPY src/main.py /usr/bin/train
# #8 CACHED
#
# #9 [7/9] RUN apt-get update &&     apt-get -y upgrade &&     apt-get install -y build-essential libblas-dev gcc &&     rm -rf /var/lib/apt/lists/* &&    apt-get clean
# #9 CACHED
#
# #10 [4/9] COPY src/report/ /usr/bin/report
# #10 CACHED
#
# #11 [8/9] RUN pip3 install --no-cache-dir -U pip setuptools wheel &&     pip3 install --no-cache-dir -r /usr/bin/elasticity/requirements.txt
# #11 CACHED
#
# #12 [2/9] COPY src/ql_toolkit/ /usr/bin/ql_toolkit
# #12 CACHED
#
# #13 [5/9] COPY src/requirements.txt /usr/bin/elasticity/
# #13 CACHED
#
# #14 [9/9] RUN chmod 755 /usr/bin/train
# #14 CACHED
#
# #15 exporting to image
# #15 exporting layers done
# #15 writing image sha256:bcec78b284d0c1b0aa60ad13db33f2491e81f8b278c74e70ad3bcea6a49ebf23 done
# #15 naming to 444642203706.dkr.ecr.us-east-1.amazonaws.com/elasticity:0.1.1 done
# #15 DONE 0.0s
# Pushing image elasticity:0.1.1 to AWS ECR (US)
# WARNING! Your password will be stored unencrypted in /home/alexia/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
# Login Succeeded
# docker push 444642203706.dkr.ecr.us-east-1.amazonaws.com/elasticity:0.1.1
# The push refers to repository [444642203706.dkr.ecr.us-east-1.amazonaws.com/elasticity]
# 7226a37984e2: Preparing
# a238a45b64fd: Preparing
# 0cefa65d744d: Preparing
# 4b26d9e2b8cf: Preparing
# 46903b738cce: Preparing
# d57b11fd3b23: Preparing
# 114de63279f6: Preparing
# 6afc14c2da4f: Preparing
# d8815e8a268d: Preparing
# 8655910e6b5f: Preparing
# 355bb094feb8: Preparing
# ed123c9f1a56: Preparing
# 92770f546e06: Preparing
# 6afc14c2da4f: Waiting
# ed123c9f1a56: Waiting
# 92770f546e06: Waiting
# d8815e8a268d: Waiting
# 8655910e6b5f: Waiting
# 355bb094feb8: Waiting
# d57b11fd3b23: Waiting
# 114de63279f6: Waiting
# 4b26d9e2b8cf: Layer already exists
# 46903b738cce: Layer already exists
# 7226a37984e2: Layer already exists
# a238a45b64fd: Layer already exists
# 0cefa65d744d: Layer already exists
# d57b11fd3b23: Layer already exists
# 114de63279f6: Layer already exists
# 355bb094feb8: Layer already exists
# 6afc14c2da4f: Layer already exists
# 8655910e6b5f: Layer already exists
# d8815e8a268d: Layer already exists
# 92770f546e06: Layer already exists
# ed123c9f1a56: Layer already exists
# 0.1.1: digest: sha256:dd12bc526ea3e80934d7cee1e1ca48e18d87e48234c145eed8a9a86d18d3bddc size: 3047
#
# Building docker image elasticity:0.1.1 for EU data center
# DOCKER_BUILDKIT=1 docker build --platform linux/amd64 --ssh default -t 444642203706.dkr.ecr.eu-central-1.amazonaws.com/elasticity:0.1.1 .
# #0 building with "default" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 682B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.11.6-slim-bookworm
# #2 DONE 1.1s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 300B done
# #3 DONE 0.0s
#
# #4 [1/9] FROM docker.io/library/python:3.11.6-slim-bookworm@sha256:cc758519481092eb5a4a5ab0c1b303e288880d59afc601958d19e95b300bc86b
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 3.04kB done
# #5 DONE 0.0s
#
# #6 [5/9] COPY src/requirements.txt /usr/bin/elasticity/
# #6 CACHED
#
# #7 [2/9] COPY src/ql_toolkit/ /usr/bin/ql_toolkit
# #7 CACHED
#
# #8 [3/9] COPY src/elasticity/ /usr/bin/elasticity
# #8 CACHED
#
# #9 [8/9] RUN pip3 install --no-cache-dir -U pip setuptools wheel &&     pip3 install --no-cache-dir -r /usr/bin/elasticity/requirements.txt
# #9 CACHED
#
# #10 [4/9] COPY src/report/ /usr/bin/report
# #10 CACHED
#
# #11 [6/9] COPY src/main.py /usr/bin/train
# #11 CACHED
#
# #12 [7/9] RUN apt-get update &&     apt-get -y upgrade &&     apt-get install -y build-essential libblas-dev gcc &&     rm -rf /var/lib/apt/lists/* &&    apt-get clean
# #12 CACHED
#
# #13 [9/9] RUN chmod 755 /usr/bin/train
# #13 CACHED
#
# #14 exporting to image
# #14 exporting layers done
# #14 writing image sha256:bcec78b284d0c1b0aa60ad13db33f2491e81f8b278c74e70ad3bcea6a49ebf23 done
# #14 naming to 444642203706.dkr.ecr.eu-central-1.amazonaws.com/elasticity:0.1.1 done
# #14 DONE 0.0s
# Pushing image elasticity:0.1.1 to AWS ECR (EU)
# WARNING! Your password will be stored unencrypted in /home/alexia/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
# Login Succeeded
# docker push 444642203706.dkr.ecr.eu-central-1.amazonaws.com/elasticity:0.1.1
# The push refers to repository [444642203706.dkr.ecr.eu-central-1.amazonaws.com/elasticity]
# 7226a37984e2: Preparing
# a238a45b64fd: Preparing
# 0cefa65d744d: Preparing
# 4b26d9e2b8cf: Preparing
# 46903b738cce: Preparing
# d57b11fd3b23: Preparing
# 114de63279f6: Preparing
# 6afc14c2da4f: Preparing
# d8815e8a268d: Preparing
# 8655910e6b5f: Preparing
# 355bb094feb8: Preparing
# ed123c9f1a56: Preparing
# 92770f546e06: Preparing
# d8815e8a268d: Waiting
# d57b11fd3b23: Waiting
# 114de63279f6: Waiting
# 8655910e6b5f: Waiting
# 355bb094feb8: Waiting
# 92770f546e06: Waiting
# 6afc14c2da4f: Waiting
# ed123c9f1a56: Waiting
# a238a45b64fd: Layer already exists
# 0cefa65d744d: Layer already exists
# 4b26d9e2b8cf: Layer already exists
# 7226a37984e2: Layer already exists
# 46903b738cce: Layer already exists
# 6afc14c2da4f: Layer already exists
# d57b11fd3b23: Layer already exists
# 114de63279f6: Layer already exists
# d8815e8a268d: Layer already exists
# 8655910e6b5f: Layer already exists
# 355bb094feb8: Layer already exists
# 92770f546e06: Layer already exists
# ed123c9f1a56: Layer already exists
# 0.1.1: digest: sha256:dd12bc526ea3e80934d7cee1e1ca48e18d87e48234c145eed8a9a86d18d3bddc size: 3047

# %% [markdown]
# ## Prepare Sagemaker params

# %%
role = environ.get("SGMKR_ROLE")
# role = sagemaker.get_execution_role()

s3_output_dir = f"s3://{bucket}/data_science/sagemaker/job_artifacts/{proj_name}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 role = environ.get("SGMKR_ROLE")
#       2 # role = sagemaker.get_execution_role()
# ----> 4 s3_output_dir = f"s3://{bucket}/data_science/sagemaker/job_artifacts/{proj_name}"
#
# NameError: name 'bucket' is not defined

# %%
role
# Out:
# 'arn:aws:iam::444642203706:role/service-role/AmazonSageMaker-ExecutionRole-20221018T092338'

# %%
def get_sess_params(is_local: bool):
    if is_local:
        sess = sagemaker.LocalSession(default_bucket=bucket)
        train_instance = "local"
        deploy_instance = "local"
    else:
        sess = sagemaker.Session(default_bucket=bucket)
        train_instance = "ml.m5.2xlarge"
        deploy_instance = "ml.m5.2xlarge"
    account_id = sess.boto_session.client('sts').get_caller_identity()['Account']
    region = sess.boto_session.region_name
    return sess, train_instance, deploy_instance, account_id, region

# %% [markdown]
# ## Run Sagemaker job in local mode

# %%
job_id = f"{proj_name}-{datetime.strftime(datetime.now(), format='%Y-%m-%dT%H-%M')}"

print(f"Preparing to run local-{job_id}:{img_tag}")

sess, train_instance, deploy_instance, account_id, region = get_sess_params(is_local=True)

estimator_local = Estimator(
    image_uri=f"{account_id}.dkr.ecr.{region}.amazonaws.com/{proj_name}:{img_tag}",
    sagemaker_sess=sess,
    role=role,
    instance_type=train_instance,
    instance_count=1,
    output_path=s3_output_dir,
    hyperparameters={
        "data_center": data_center,
        "config": "config_qa",
    }
)

estimator_local.fit(job_name=f"local-{job_id}")
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# Preparing to run local-elasticity-2024-05-20T14-36:0.1.1
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# INFO:sagemaker:Creating training-job with name: local-elasticity-2024-05-20T14-36
# INFO:sagemaker.local.image:'Docker Compose' found using Docker CLI.
# INFO:sagemaker.local.local_session:Starting training job
# INFO:sagemaker.local.image:Using the long-lived AWS credentials found in session
# INFO:sagemaker.local.image:docker compose file:
# networks:
#   sagemaker-local:
#     name: sagemaker-local
# services:
#   algo-1-gjsu2:
#     command: train
#     container_name: 1l5wzwavwb-algo-1-gjsu2
#     environment:
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     image: 444642203706.dkr.ecr.eu-central-1.amazonaws.com/elasticity:0.1.1
#     networks:
#       sagemaker-local:
#         aliases:
#         - algo-1-gjsu2
#     stdin_open: true
#     tty: true
#     volumes:
#     - /tmp/tmpwn6l3r0p/algo-1-gjsu2/output/data:/opt/ml/output/data
#     - /tmp/tmpwn6l3r0p/algo-1-gjsu2/input:/opt/ml/input
#     - /tmp/tmpwn6l3r0p/algo-1-gjsu2/output:/opt/ml/output
#     - /tmp/tmpwn6l3r0p/model:/opt/ml/model
# version: '2.3'
#
# INFO:sagemaker.local.image:docker command: docker compose -f /tmp/tmpwn6l3r0p/docker-compose.yaml up --build --abort-on-container-exit
# time="2024-05-20T14:36:05+03:00" level=warning msg="/tmp/tmpwn6l3r0p/docker-compose.yaml: `version` is obsolete"
#  Network sagemaker-local  Creating
#  Network sagemaker-local  Created
#  Container 1l5wzwavwb-algo-1-gjsu2  Creating
#  Container 1l5wzwavwb-algo-1-gjsu2  Created
# Attaching to 1l5wzwavwb-algo-1-gjsu2
# 1l5wzwavwb-algo-1-gjsu2  | Traceback (most recent call last):
# 1l5wzwavwb-algo-1-gjsu2  |   File "/usr/bin/train", line 13, in <module>
# 1l5wzwavwb-algo-1-gjsu2  |     import elasticity.utils.plot_demands as plot_demands
# 1l5wzwavwb-algo-1-gjsu2  |   File "/usr/bin/elasticity/utils/plot_demands.py", line 11, in <module>
# 1l5wzwavwb-algo-1-gjsu2  |     from elasticity.model.model import estimate_coefficients
# 1l5wzwavwb-algo-1-gjsu2  |   File "/usr/bin/elasticity/model/model.py", line 9, in <module>
# 1l5wzwavwb-algo-1-gjsu2  |     from pydantic import BaseModel
# 1l5wzwavwb-algo-1-gjsu2  | ModuleNotFoundError: No module named 'pydantic'
# INFO:root:creating /tmp/tmpwn6l3r0p/artifacts/output/data
# 1l5wzwavwb-algo-1-gjsu2 exited with code 1
# Aborting on container exit...
#  Container 1l5wzwavwb-algo-1-gjsu2  Stopping
#  Container 1l5wzwavwb-algo-1-gjsu2  Stopped
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 20
#       5 sess, train_instance, deploy_instance, account_id, region = get_sess_params(is_local=True)
#       7 estimator_local = Estimator(
#       8     image_uri=f"{account_id}.dkr.ecr.{region}.amazonaws.com/{proj_name}:{img_tag}",
#       9     sagemaker_sess=sess,
#    (...)
#      17     }
#      18 )
# ---> 20 estimator_local.fit(job_name=f"local-{job_id}")
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/estimator.py:1338, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1335 self._prepare_for_training(job_name=job_name)
#    1337 experiment_config = check_and_get_run_experiment_config(experiment_config)
# -> 1338 self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#    1339 self.jobs.append(self.latest_training_job)
#    1340 if wait:
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/estimator.py:2437, in _TrainingJob.start_new(cls, estimator, inputs, experiment_config)
#    2412 """Create a new Amazon SageMaker training job from the estimator.
#    2413
#    2414 Args:
#    (...)
#    2433     all information about the started training job.
#    2434 """
#    2435 train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 2437 estimator.sagemaker_session.train(**train_args)
#    2439 return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/session.py:982, in Session.train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, training_image_config, infra_check_config, container_entry_point, container_arguments, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config, environment, retry_strategy, remote_debug_config)
#     979     logger.debug("train request: %s", json.dumps(request, indent=4))
#     980     self.sagemaker_client.create_training_job(**request)
# --> 982 self._intercept_create_request(train_request, submit, self.train.__name__)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/session.py:6421, in Session._intercept_create_request(self, request, create, func_name)
#    6404 def _intercept_create_request(
#    6405     self,
#    6406     request: typing.Dict,
#    (...)
#    6409     # pylint: disable=unused-argument
#    6410 ):
#    6411     """This function intercepts the create job request.
#    6412
#    6413     PipelineSession inherits this Session class and will override
#    (...)
#    6419         func_name (str): the name of the function needed intercepting
#    6420     """
# -> 6421     return create(request)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/session.py:980, in Session.train.<locals>.submit(request)
#     978 logger.info("Creating training-job with name: %s", job_name)
#     979 logger.debug("train request: %s", json.dumps(request, indent=4))
# --> 980 self.sagemaker_client.create_training_job(**request)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/local/local_session.py:212, in LocalSagemakerClient.create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, Environment, **kwargs)
#     210 hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     211 logger.info("Starting training job")
# --> 212 training_job.start(
#     213     InputDataConfig, OutputDataConfig, hyperparameters, Environment, TrainingJobName
#     214 )
#     216 LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/local/entities.py:246, in _LocalTrainingJob.start(self, input_data_config, output_data_config, hyperparameters, environment, job_name)
#     243 self.state = self._TRAINING
#     244 self.environment = environment
# --> 246 self.model_artifacts = self.container.train(
#     247     input_data_config, output_data_config, hyperparameters, environment, job_name
#     248 )
#     249 self.end_time = datetime.datetime.now()
#     250 self.state = self._COMPLETED
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/local/image.py:314, in _SageMakerContainer.train(self, input_data_config, output_data_config, hyperparameters, environment, job_name)
#     309 process = subprocess.Popen(
#     310     compose_command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT
#     311 )
#     313 try:
# --> 314     _stream_output(process)
#     315 finally:
#     316     artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/local/image.py:1021, in _stream_output(process)
#    1018     exit_code = process.poll()
#    1020 if exit_code not in [0, 130]:
# -> 1021     raise RuntimeError(f"Failed to run: {process.args}. Process exited with code: {exit_code}")
#    1023 return exit_code
#
# RuntimeError: Failed to run: ['docker', 'compose', '-f', '/tmp/tmpwn6l3r0p/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit']. Process exited with code: 1

# %% [markdown]
# ## Run on EC2

# %%
job_id = f"{proj_name}-complete-run-test-m5x12-{datetime.strftime(datetime.now(), format='%Y-%m-%dT%H-%M')}"

print(f"Preparing to run {job_id}:{img_tag}")

sess, train_instance, deploy_instance, account_id, region = get_sess_params(is_local=False)

estimator_local = Estimator(
    image_uri=f"{account_id}.dkr.ecr.{region}.amazonaws.com/{proj_name}:{img_tag}",
    sagemaker_sess=sess,
    role=role,
    
    use_spot_instances=True,
    max_run=21600,
    max_wait=21600,
    instance_type=train_instance,
    volume_size=12,
    instance_count=1,
    output_path=s3_output_dir,
    hyperparameters={
        "data_center": data_center,
        "config": "config_prod_eu",
        'project_name': proj_name,
        "local": False
    }
)

estimator_local.fit(job_name=f"{job_id}")
# Out:
# Preparing to run elasticity-complete-run-test-m5x12-2024-06-04T18-43:0.1.1
# INFO:sagemaker:Creating training-job with name: elasticity-complete-run-test-m5x12-2024-06-04T18-43
# 2024-06-04 15:43:19 Starting - Starting the training job...
# 2024-06-04 15:43:35 Starting - Preparing the instances for training...
# 2024-06-04 15:44:13 Downloading - Downloading the training image
# 2024-06-04 15:44:13 Training - Training image download completed. Training in progress..Setting up runtime environment...
# Reading arguments from /opt/ml/input/config (inside container)
# [2024-06-04 15:44:23] [INFO    ]: Setting up runtime environment... (setup.py/run_setup)
# Job CLI args:
# config: config_prod_eu (<class 'str'>)
# data_center: eu (<class 'str'>)
# local: False (<class 'bool'>)
# project_name: elasticity (<class 'str'>)
# [2024-06-04 15:44:23] [INFO    ]: Running on the EU Data Center (quicklizard-eu-central Bucket) (setup.py/run_setup)
# [2024-06-04 15:44:23] [INFO    ]: Setup complete! (setup.py/run_setup)
# [2024-06-04 15:44:23] [INFO    ]: args_dict: {'config': 'config_prod_eu', 'data_center': 'eu', 'local': False, 'project_name': 'elasticity', 'aws_key': '', 'aws_secret': ''} (train/setup_environment)
# [2024-06-04 15:44:23] [INFO    ]: config: {'client_keys': {'elkjopno': {'attr_name': ['cgmcode'], 'channels': ['default']}, 'pieperde': {'attr_name': ['ql_pricing_group'], 'channels': ['default']}}} (train/setup_environment)
# [2024-06-04 15:44:23] [INFO    ]: client_keys_map: {'elkjopno': {'attr_name': ['cgmcode'], 'channels': ['default']}, 'pieperde': {'attr_name': ['ql_pricing_group'], 'channels': ['default']}} (train/setup_environment)
# [2024-06-04 15:44:23] [INFO    ]: start_date: 2023-06-01 (train/setup_environment)
# [2024-06-04 15:44:23] [INFO    ]: end_date: 2024-05-01 (train/setup_environment)
# [2024-06-04 15:44:23] [INFO    ]:  ------ Running in Production mode ------  (train/setup_environment)
# [2024-06-04 15:44:23] [INFO    ]: Processing elkjopno - default - attr: cgmcode (train/process_client_channel)
# [2024-06-04 15:44:23] [INFO    ]: start_date: 2023-06-01 (preprocessing.py/read_and_preprocess)
# [2024-06-04 15:44:23] [INFO    ]: end_date: 2024-05-01 (preprocessing.py/read_and_preprocess)
# [2024-06-04 15:44:23] [INFO    ]: reading: 2024-05-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:27] [INFO    ]: Number of inventory less or equal to 0: 3909318 (preprocessing.py/read_data)
# [2024-06-04 15:44:27] [INFO    ]: Number of negative unit: 4809 (preprocessing.py/read_data)
# [2024-06-04 15:44:27] [INFO    ]: Total uid: 13688 (utils.py/get_revenue)
# [2024-06-04 15:44:30] [INFO    ]: number of uid ok: 0 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:30] [INFO    ]: reading: 2024-04-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:34] [INFO    ]: Number of inventory less or equal to 0: 3999249 (preprocessing.py/read_data)
# [2024-06-04 15:44:34] [INFO    ]: Number of negative unit: 5360 (preprocessing.py/read_data)
# [2024-06-04 15:44:37] [INFO    ]: number of uid ok: 3 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:37] [INFO    ]: reading: 2024-03-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:41] [INFO    ]: Number of inventory less or equal to 0: 3986111 (preprocessing.py/read_data)
# [2024-06-04 15:44:41] [INFO    ]: Number of negative unit: 4765 (preprocessing.py/read_data)
# [2024-06-04 15:44:45] [INFO    ]: number of uid ok: 21 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:45] [INFO    ]: reading: 2024-02-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:49] [INFO    ]: Number of inventory less or equal to 0: 4189765 (preprocessing.py/read_data)
# [2024-06-04 15:44:49] [INFO    ]: Number of negative unit: 5764 (preprocessing.py/read_data)
# [2024-06-04 15:44:54] [INFO    ]: number of uid ok: 130 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:54] [INFO    ]: reading: 2024-01-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:44:57] [INFO    ]: Number of inventory less or equal to 0: 2748542 (preprocessing.py/read_data)
# [2024-06-04 15:44:57] [INFO    ]: Number of negative unit: 8135 (preprocessing.py/read_data)
# [2024-06-04 15:45:02] [INFO    ]: number of uid ok: 251 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:02] [INFO    ]: reading: 2023-12-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:04] [INFO    ]: Number of inventory less or equal to 0: 1256439 (preprocessing.py/read_data)
# [2024-06-04 15:45:05] [INFO    ]: Number of negative unit: 7186 (preprocessing.py/read_data)
# [2024-06-04 15:45:10] [INFO    ]: number of uid ok: 397 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:11] [INFO    ]: reading: 2023-11-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:13] [INFO    ]: Number of inventory less or equal to 0: 1476836 (preprocessing.py/read_data)
# [2024-06-04 15:45:13] [INFO    ]: Number of negative unit: 6192 (preprocessing.py/read_data)
# [2024-06-04 15:45:20] [INFO    ]: number of uid ok: 537 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:20] [INFO    ]: reading: 2023-10-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:22] [INFO    ]: Number of inventory less or equal to 0: 1424767 (preprocessing.py/read_data)
# [2024-06-04 15:45:22] [INFO    ]: Number of negative unit: 6314 (preprocessing.py/read_data)
# [2024-06-04 15:45:29] [INFO    ]: number of uid ok: 661 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:30] [INFO    ]: reading: 2023-09-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:32] [INFO    ]: Number of inventory less or equal to 0: 1414167 (preprocessing.py/read_data)
# [2024-06-04 15:45:32] [INFO    ]: Number of negative unit: 5828 (preprocessing.py/read_data)
# [2024-06-04 15:45:39] [INFO    ]: number of uid ok: 764 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:39] [INFO    ]: reading: 2023-08-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:42] [INFO    ]: Number of inventory less or equal to 0: 1481830 (preprocessing.py/read_data)
# [2024-06-04 15:45:42] [INFO    ]: Number of negative unit: 5831 (preprocessing.py/read_data)
# [2024-06-04 15:45:50] [INFO    ]: number of uid ok: 874 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:50] [INFO    ]: reading: 2023-07-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:45:52] [INFO    ]: Number of inventory less or equal to 0: 1478808 (preprocessing.py/read_data)
# [2024-06-04 15:45:52] [INFO    ]: Number of negative unit: 5318 (preprocessing.py/read_data)
# [2024-06-04 15:46:00] [INFO    ]: number of uid ok: 957 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:46:01] [INFO    ]: reading: 2023-06-01 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:46:03] [INFO    ]: Number of inventory less or equal to 0: 1427967 (preprocessing.py/read_data)
# [2024-06-04 15:46:03] [INFO    ]: Number of negative unit: 5260 (preprocessing.py/read_data)
# [2024-06-04 15:46:11] [INFO    ]: number of uid ok: 1061 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:46:12] [INFO    ]: Number of unique user IDs: 1061 (preprocessing.py/progressive_monthly_aggregate)
# [2024-06-04 15:46:12] [INFO    ]: Number of uid with outliers: 210 (preprocessing.py/read_and_preprocess)
# [2024-06-04 15:46:12] [INFO    ]: start_date: 2023-06-01 (preprocessing.py/read_and_preprocess)
# [2024-06-04 15:46:12] [INFO    ]: end_date: 2024-05-01 (preprocessing.py/read_and_preprocess)
# [2024-06-04 15:46:12] [INFO    ]: Total number of uid: 13688 (preprocessing.py/read_and_preprocess)
# [2024-06-04 15:46:12] [INFO    ]: total_revenue: 1007962243.6800001 (preprocessing.py/read_and_preprocess)
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: divide by zero encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: divide by zero encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: divide by zero encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: divide by zero encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# ...
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:807: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2      # concentrated likelihood
# [2024-06-04 15:48:32] [ERROR   ]: Error getting segmentation data: Usecols do not match columns, columns expected but not found: ['ranking_score_rank', 'ranking_score'] (group.py/data_for_group_elasticity)
# [2024-06-04 15:48:32] [ERROR   ]: No group elasticity data available. (group.py/add_group_elasticity)
# [2024-06-04 15:48:32] [INFO    ]: Quality test: quality_test
# True    475
# Name: count, dtype: int64 (train/process_client_channel)
# [2024-06-04 15:48:32] [INFO    ]: Test high: quality_test_high
# True     355
# False    120
# Name: count, dtype: int64 (train/process_client_channel)
# [2024-06-04 15:48:32] [ERROR   ]: Error processing pieperde - default: 'type' (train/process_client_channel)
# [2024-06-04 15:48:32] [ERROR   ]: Error occurred in /usr/bin/train - 'type'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'type'
# The above exception was the direct cause of the following exception:
# Traceback (most recent call last):
#   File "/usr/bin/train", line 130, in process_client_channel
#     f"Type: {df_results[df_results.result_to_push]['type'].value_counts()}"
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'type'
#  (train/process_client_channel)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'type'
# The above exception was the direct cause of the following exception:
# Traceback (most recent call last):
#   File "/usr/bin/train", line 130, in process_client_channel
#     f"Type: {df_results[df_results.result_to_push]['type'].value_counts()}"
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'type'
# During handling of the above exception, another exception occurred:
# Traceback (most recent call last):
#   File "/usr/bin/train", line 225, in <module>
#     run()
#   File "/usr/bin/train", line 202, in run
#     data_report = process_client_channel(
#                   ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/bin/train", line 182, in process_client_channel
#     data_report = report.add_error_run(
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/bin/report/report.py", line 199, in add_error_run
#     data_report.append(
#     ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'append'
#
# 2024-06-04 15:48:45 Uploading - Uploading generated training model
# 2024-06-04 15:48:45 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# Cell In[7], line 27
#       5 sess, train_instance, deploy_instance, account_id, region = get_sess_params(is_local=False)
#       7 estimator_local = Estimator(
#       8     image_uri=f"{account_id}.dkr.ecr.{region}.amazonaws.com/{proj_name}:{img_tag}",
#       9     sagemaker_sess=sess,
#    (...)
#      24     }
#      25 )
# ---> 27 estimator_local.fit(job_name=f"{job_id}")
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/estimator.py:1341, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1339 self.jobs.append(self.latest_training_job)
#    1340 if wait:
# -> 1341     self.latest_training_job.wait(logs=logs)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/estimator.py:2680, in _TrainingJob.wait(self, logs)
#    2678 # If logs are requested, call logs_for_jobs.
#    2679 if logs != "None":
# -> 2680     self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    2681 else:
#    2682     self.sagemaker_session.wait_for_job(self.job_name)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/session.py:5760, in Session.logs_for_job(self, job_name, wait, poll, log_type, timeout)
#    5739 def logs_for_job(self, job_name, wait=False, poll=10, log_type="All", timeout=None):
#    5740     """Display logs for a given training job, optionally tailing them until job is complete.
#    5741
#    5742     If the output is a tty or a Jupyter cell, it will be color-coded
#    (...)
#    5758         exceptions.UnexpectedStatusException: If waiting and the training job fails.
#    5759     """
# -> 5760     _logs_for_job(self, job_name, wait, poll, log_type, timeout)
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/session.py:7989, in _logs_for_job(sagemaker_session, job_name, wait, poll, log_type, timeout)
#    7986             last_profiler_rule_statuses = profiler_rule_statuses
#    7988 if wait:
# -> 7989     _check_job_status(job_name, description, "TrainingJobStatus")
#    7990     if dot:
#    7991         print()
#
# File ~/workspace/elasticity/.venv/lib/python3.11/site-packages/sagemaker/session.py:8042, in _check_job_status(job, desc, status_key_name)
#    8036 if "CapacityError" in str(reason):
#    8037     raise exceptions.CapacityError(
#    8038         message=message,
#    8039         allowed_statuses=["Completed", "Stopped"],
#    8040         actual_status=status,
#    8041     )
# -> 8042 raise exceptions.UnexpectedStatusException(
#    8043     message=message,
#    8044     allowed_statuses=["Completed", "Stopped"],
#    8045     actual_status=status,
#    8046 )
#
# UnexpectedStatusException: Error for Training job elasticity-complete-run-test-m5x12-2024-06-04T18-43: Failed. Reason: AlgorithmError: , exit code: 1
